# %% [markdown]
# <a href="https://colab.research.google.com/github/shannanliew/shannanliew.github.io/blob/main/obesity_rates_countries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from google.colab import files

# Set the URL to get our data from
url = "https://worldpopulationreview.com/country-rankings/most-obese-countries"

# Send a GET request to fetch the page content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")

    # Locate the main <tbody> containing the full list of countries
    table_body = soup.find("tbody", {"class": "relative z-10 text-sm"})

    # Lists to store country names and obesity rates
    countries = []
    obesity_rates = []

    # Iterate through each row in the table body
    for row in table_body.find_all("tr"):
        # Get the country name from the <th> element
        country = row.find("th").text.strip()

        # Get all <td> elements in the row
        cells = row.find_all("td")

        # Check if there are at least 4 <td> elements, to avoid index errors
        if len(cells) >= 4:
            obesity_rate_both = cells[3].text.strip()  # Extract the 4th <td> element
        else:
            obesity_rate_both = ""  # Assign empty string if the data is missing

        # Append data to the lists
        countries.append(country)
        obesity_rates.append(obesity_rate_both)

    # Create a DataFrame with the scraped data
    df = pd.DataFrame({
        "Country": countries,
        "Obesity Rate - Both (%)": obesity_rates
    })

    # Remove rows with missing or empty values in the "Obesity Rate - Both (%)" column
    df = df[df["Obesity Rate - Both (%)"] != ""]
    df.reset_index(drop=True, inplace=True)

    # Display the DataFrame without rows with missing data
    print(df)

    # Export the DataFrame to a CSV file
    df.to_csv("obesity_rates_countries.csv", index=False)

    files.download("obesity_rates_countries.csv")

else:
    print("Failed to retrieve the page. Status code:", response.status_code)
# Out:
#                               Country Obesity Rate - Both (%)
# 0                        Cook Islands                   55.9%
# 1                               Nauru                     61%
# 2                                Niue                     50%
# 3                               Samoa                   47.3%
# 4                               Tonga                   48.2%
# 5                              Tuvalu                   51.6%
# 6                            Kiribati                     46%
# 7                         Saint Lucia                   19.7%
# 8                          Micronesia                   45.8%
# 9                               Egypt                     32%
# 10                             Kuwait                   37.9%
# 11                   Marshall Islands                   52.9%
# 12              Saint Kitts and Nevis                   22.9%
# 13                              Palau                   55.3%
# 14                              Qatar                   35.1%
# 15                             Belize                   24.1%
# 16                             Jordan                   35.5%
# 17                      United States                   36.2%
# 18                               Iraq                   30.4%
# 19                       Saudi Arabia                   35.4%
# 20               United Arab Emirates                   31.7%
# 21                              Syria                   27.8%
# 22                              Libya                   32.5%
# 23                             Mexico                   28.9%
# 24                              Chile                     28%
# 25                        New Zealand                   30.8%
# 26                            Bahamas                   31.6%
# 27                             Turkey                   32.1%
# 28                            Jamaica                   24.7%
# 29                           Barbados                   23.1%
# 30                          Argentina                   28.3%
# 31                        El Salvador                   24.6%
# 32                               Fiji                   30.2%
# 33                            Lebanon                     32%
# 34                            Georgia                   21.7%
# 35                Trinidad and Tobago                   18.6%
# 36                            Ireland                   25.3%
# 37                            Croatia                   24.4%
# 38                            Uruguay                   27.9%
# 39                       South Africa                   28.3%
# 40                            Ecuador                   19.9%
# 41                            Hungary                   26.4%
# 42                             Israel                   26.1%
# 43                         Costa Rica                   25.7%
# 44                          Nicaragua                   23.7%
# 45                             Brunei                   14.1%
# 46   Saint Vincent and the Grenadines                   23.7%
# 47                     United Kingdom                   27.8%
# 48                          Australia                     29%
# 49                     Czech Republic                     26%
# 50                         Azerbaijan                   19.9%
# 51                             Greece                   24.9%
# 52                              Malta                   28.9%
# 53                            Moldova                   18.9%
# 54                            Grenada                   21.3%
# 55                           Dominica                   27.9%
# 56                             Canada                   29.4%
# 57                         Uzbekistan                   16.6%
# 58                            Romania                   22.5%
# 59                             Panama                   22.7%
# 60                           Honduras                   21.4%
# 61                    North Macedonia                   22.4%
# 62                             Cyprus                   21.8%
# 63                           Eswatini                   16.5%
# 64                             Poland                   23.1%
# 65                               Peru                   19.7%
# 66                          Venezuela                   25.6%
# 67                           Paraguay                   20.3%
# 68                             Norway                   23.1%
# 69                            Albania                   21.7%
# 70                             Latvia                   23.6%
# 71                         Seychelles                     14%
# 72                Antigua and Barbuda                   18.9%
# 73                            Andorra                   25.6%
# 74                             Brazil                   22.1%
# 75                            Germany                   22.3%
# 76                            Ukraine                   24.1%
# 77                          Guatemala                   21.2%
# 78                            Bolivia                   20.2%
# 79                            Belarus                   24.5%
# 80                       Turkmenistan                   18.6%
# 81                         Kyrgyzstan                   16.6%
# 82                           Slovenia                   20.2%
# 83                 Dominican Republic                   27.6%
# 84                         Montenegro                   23.3%
# 85                           Suriname                   26.4%
# 86                         Kazakhstan                     21%
# 87                           Bulgaria                     25%
# 88                           Slovakia                   20.5%
# 89                          Lithuania                   26.3%
# 90                            Estonia                   21.2%
# 91                             Guyana                   20.2%
# 92                            Tunisia                   26.9%
# 93                               Oman                     27%
# 94                            Armenia                   20.2%
# 95                    Solomon Islands                   22.5%
# 96                         Luxembourg                   22.6%
# 97                             Russia                   23.1%
# 98                           Colombia                   22.3%
# 99                           Mongolia                   20.6%
# 100                           Iceland                   21.9%
# 101                           Vanuatu                   25.2%
# 102                              Iran                   25.8%
# 103                           Belgium                   22.1%
# 104                        Tajikistan                   14.2%
# 105                            Serbia                   21.5%
# 106                           Morocco                   26.1%
# 107                            Sweden                   20.6%
# 108                             Spain                   23.8%
# 109                           Finland                   22.2%
# 110            Bosnia and Herzegovina                   17.9%
# 111                          Malaysia                   15.6%
# 112                             Italy                   19.9%
# 113                       Netherlands                   20.4%
# 114                              Cuba                   24.6%
# 115                  Papua New Guinea                   21.3%
# 116                          Portugal                   20.8%
# 117                           Austria                   20.1%
# 118                           Algeria                   27.4%
# 119                          Maldives                    8.6%
# 120                             Haiti                   22.7%
# 121                           Denmark                   19.7%
# 122                       Switzerland                   19.5%
# 123                             Gabon                     15%
# 124                         Mauritius                   10.8%
# 125                            France                   21.6%
# 126                        Mauritania                   12.7%
# 127                           Lesotho                   16.6%
# 128                           Bahrain                   29.8%
# 129             Sao Tome and Principe                   12.4%
# 130                           Comoros                    7.8%
# 131                        Cape Verde                   11.8%
# 132                          Thailand                     10%
# 133                          Cameroon                   11.4%
# 134                          Botswana                   18.9%
# 135                           Namibia                   17.2%
# 136                       North Korea                    6.8%
# 137                           Liberia                    9.9%
# 138                            Gambia                   10.3%
# 139                 Equatorial Guinea                      8%
# 140                          Djibouti                   13.5%
# 141                          Pakistan                    8.6%
# 142                             Ghana                   10.9%
# 143                            Bhutan                    6.4%
# 144                             China                    6.2%
# 145                       South Korea                    4.7%
# 146                             Yemen                   17.1%
# 147                       Ivory Coast                   10.3%
# 148                          Zimbabwe                   15.5%
# 149                              Togo                    8.4%
# 150                         Singapore                    6.1%
# 151                             Benin                    9.6%
# 152                       Afghanistan                    5.5%
# 153                     Guinea Bissau                    9.5%
# 154                             Kenya                    7.1%
# 155                            Angola                    8.2%
# 156                           Nigeria                    8.9%
# 157                       Philippines                    6.4%
# 158                          Tanzania                    8.4%
# 159                           Somalia                    8.3%
# 160             Republic of the Congo                    9.6%
# 161                         Indonesia                    6.9%
# 162                         Sri Lanka                    5.2%
# 163                              Mali                    8.6%
# 164                           Senegal                    8.8%
# 165                            Malawi                    5.8%
# 166                            Guinea                    7.7%
# 167                              Laos                    5.3%
# 168          Central African Republic                    7.5%
# 169                        Mozambique                    7.2%
# 170                             Japan                    4.3%
# 171                      Sierra Leone                    8.7%
# 172                           Myanmar                    5.8%
# 173                            Zambia                    8.1%
# 174                            Uganda                    5.3%
# 175                             Nepal                    4.1%
# 176                      Burkina Faso                    5.6%
# 177                          Cambodia                    3.9%
# 178                            Rwanda                    5.8%
# 179                          DR Congo                    6.7%
# 180                           Vietnam                    2.1%
# 181                              Chad                    6.1%
# 182                             India                    3.9%
# 183                             Niger                    5.5%
# 184                        Bangladesh                    3.6%
# 185                           Burundi                    5.4%
# 186                        Madagascar                    5.3%
# 187                       Timor Leste                    3.8%
# 188                           Eritrea                      5%
# 189                          Ethiopia                    4.5%
